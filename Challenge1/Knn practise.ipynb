# %%
import numpy as np

# %%
list1=list(np.random.randint(1,100,10))
list2=list(np.random.randint(50,100,10))

# %%
distance=[]
for i in list1:
    for j in list2:
        dista(i-j)
# Out:
# -12
# -23
# -25
# -21
# -42
# -53
# -13
# -42
# -37
# -61
# 9
# -2
# -4
# 0
# -21
# -32
# 8
# -21
# -16
# -40
# -5
# -16
# -18
# -14
# -35
# -46
# -6
# -35
# -30
# -54
# -13
# -24
# -26
# -22
# -43
# -54
# -14
# -43
# -38
# -62
# 45
# 34
# 32
# 36
# 15
# 4
# 44
# 15
# 20
# -4
# -44
# -55
# -57
# -53
# -74
# -85
# -45
# -74
# -69
# -93
# -35
# -46
# -48
# -44
# -65
# -76
# -36
# -65
# -60
# -84
# 22
# 11
# 9
# 13
# -8
# -19
# 21
# -8
# -3
# -27
# 36
# 25
# 23
# 27
# 6
# -5
# 35
# 6
# 11
# -13
# -2
# -13
# -15
# -11
# -32
# -43
# -3
# -32
# -27
# -51

# %%
#find distance
distance=[]
for i in list1:
    distance.append([])
    for j in list2:
        distance[i].append((i-j,j))
        if i==len(list1):
            break
#sorted distance        
dist_sort=[]
for i in distance:
    dist_sort.append(sorted(i,reverse=True))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-6aee4895cc10> in <module>
#       7     distance.append([])
#       8     for j in list2:
# ----> 9         distance[i].append((i-j,j))
#      10         if i==len(list1):
#      11             break
#
# IndexError: list index out of range
