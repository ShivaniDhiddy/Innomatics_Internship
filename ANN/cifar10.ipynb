# %%
import tensorflow as tf
from tensorflow.keras import datasets,layers,models,Sequential
import matplotlib.pyplot as plt
import numpy as np

# %%
(X_train,Y_train),(X_test,Y_test) = datasets.cifar10.load_data()
X_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
X_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
Y_train.shape
# Out:
# (50000, 1)

# %%
Y_train[:5]
# Out:
# array([[6],
#        [9],
#        [9],
#        [4],
#        [1]], dtype=uint8)

# %%
Y_train=Y_train.reshape(-1,)
Y_train[:5]
# Out:
# array([6, 9, 9, 4, 1], dtype=uint8)

# %%
plt.imshow(X_train[1])

# %%
classes = ["airpalne","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

# %%
def indexplot(X,y,index):
    plt.figure(figsize=(5,5))
    plt.imshow(X[index])
    plt.xlabel(classes[y[index]])

# %%
for index in range(20):
    indexplot(X_train,Y_train,index)

# %%
X_train = X_train /255
X_test  = X_test / 255

# %%
ann = models.Sequential([
    layers.Flatten(input_shape=(32,32,3)),
    layers.Dense(2000, activation="relu"),
    layers.Dense(1000, activation="relu"),
    layers.Dense(10, activation="sigmoid")
    ])
ann.compile(optimizer='SGD',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
ann.fit(X_train,Y_train,epochs=5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-ece34dddfcae> in <module>
#       5     layers.Dense(10, activation="sigmoid")
#       6     ])
# ----> 7 ann.compile(optimzer='SGD',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
#       8 ann.fit(X_train,Y_train,epochs=5)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in compile(self, optimizer, loss, metrics, loss_weights, weighted_metrics, run_eagerly, steps_per_execution, **kwargs)
#     532           steps_per_execution = kwargs.pop('experimental_steps_per_execution')
#     533
# --> 534       self._validate_compile(optimizer, metrics, **kwargs)
#     535       self._run_eagerly = run_eagerly
#     536
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in _validate_compile(self, optimizer, metrics, **kwargs)
#    2517     invalid_kwargs = set(kwargs) - {'sample_weight_mode'}
#    2518     if invalid_kwargs:
# -> 2519       raise TypeError('Invalid keyword argument(s) in `compile`: %s' %
#    2520                       (invalid_kwargs,))
#    2521
#
# TypeError: Invalid keyword argument(s) in `compile`: {'optimzer'}
