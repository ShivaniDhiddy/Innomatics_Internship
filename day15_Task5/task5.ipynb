# %%
import sqlite3
import pandas as pd

# %% [markdown]
# ### Step-1 : Load the Database

# %%
conn = sqlite3.connect('musicbrainz-cmudb2020.db')
cursor = conn.cursor()

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table'")
tables = cursor.fetchall()
print(tables)
print(len(tables))
# Out:
# [('area',), ('artist',), ('artist_alias',), ('artist_credit_name',), ('artist_credit',), ('artist_type',), ('gender',), ('language',), ('medium',), ('medium_format',), ('release',), ('release_info',), ('release_status',), ('work',), ('work_type',)]
# 15

# %% [markdown]
# Observe that we have 15 tables in this database.

# %% [markdown]
# ## Q1 (q1_sample)
#
# The purpose of this query is to make sure that the formatting of your output matches exactly the formatting of our auto-grading script.
#
# <b>Details:</b> List all types of work ordered by type ascendingly.

# %%
# Lets have a look at all columns in work_type table

cursor.execute("PRAGMA table_info('work_type')")
cols = cursor.fetchall()
for col in cols:
    print(col[1])
# Out:
# id
# name
# description

# %% [markdown]
# ### Step - 2: Check the schema

# %%
schema=pd.read_sql_query("""pragma table_info('artist')
""",conn)
schema
# Out:
#     cid              name     type  notnull dflt_value  pk
# 0     0                id  INTEGER        0       None   0
# 1     1              name     TEXT        0       None   0
# 2     2   begin_date_year  INTEGER        0       None   0
# 3     3  begin_date_month  INTEGER        0       None   0
# 4     4    begin_date_day  INTEGER        0       None   0
# 5     5     end_date_year  INTEGER        0       None   0
# 6     6    end_date_month     TEXT        0       None   0
# 7     7      end_date_day     TEXT        0       None   0
# 8     8              type  INTEGER        0       None   0
# 9     9              area  INTEGER        0       None   0
# 10   10            gender  INTEGER        0       None   0
# 11   11           comment     TEXT        0       None   0

# %%
area_schema=pd.read_sql_query("""pragma table_info('area')
""",conn)
area_schema
# Out:
#    cid     name     type  notnull dflt_value  pk
# 0    0       id  INTEGER        0       None   0
# 1    1     name     TEXT        0       None   0
# 2    2  comment     TEXT        0       None   0

# %%
artist_schema=pd.read_sql_query("""pragma table_info('artist')
""",conn)
artist_schema
# Out:
#     cid              name     type  notnull dflt_value  pk
# 0     0                id  INTEGER        0       None   0
# 1     1              name     TEXT        0       None   0
# 2     2   begin_date_year  INTEGER        0       None   0
# 3     3  begin_date_month  INTEGER        0       None   0
# 4     4    begin_date_day  INTEGER        0       None   0
# 5     5     end_date_year  INTEGER        0       None   0
# 6     6    end_date_month     TEXT        0       None   0
# 7     7      end_date_day     TEXT        0       None   0
# 8     8              type  INTEGER        0       None   0
# 9     9              area  INTEGER        0       None   0
# 10   10            gender  INTEGER        0       None   0
# 11   11           comment     TEXT        0       None   0

# %%
schema=pd.read_sql_query("""pragma table_info('artist_alias')
""",conn)
schema
# Out:
#    cid    name     type  notnull dflt_value  pk
# 0    0      id  INTEGER        0       None   0
# 1    1  artist  INTEGER        0       None   0
# 2    2    name     TEXT        0       None   0

# %%
artist_credits_schema=pd.read_sql_query("""pragma table_info('artist_credit')
""",conn)
artist_credits_schema
# Out:
#    cid          name     type  notnull dflt_value  pk
# 0    0            id  INTEGER        0       None   0
# 1    1          name     TEXT        0       None   0
# 2    2  artist_count  INTEGER        0       None   0

# %%
artist_credits_name_schema=pd.read_sql_query("""pragma table_info('artist_credit_name')
""",conn)
artist_credits_name_schema
# Out:
#    cid           name     type  notnull dflt_value  pk
# 0    0  artist_credit  INTEGER        0       None   0
# 1    1       position  INTEGER        0       None   0
# 2    2         artist  INTEGER        0       None   0
# 3    3           name     TEXT        0       None   0

# %%
artist_type_schema=pd.read_sql_query("""pragma table_info('artist_type')
""",conn)
artist_type_schema
# Out:
#    cid  name     type  notnull dflt_value  pk
# 0    0    id  INTEGER        0       None   0
# 1    1  name     TEXT        0       None   0

# %%
gender_schema=pd.read_sql_query("""pragma table_info('gender')
""",conn)
gender_schema
# Out:
#    cid         name     type  notnull dflt_value  pk
# 0    0           id  INTEGER        0       None   0
# 1    1         name     TEXT        0       None   0
# 2    2  description     TEXT        0       None   0

# %%
language_schema=pd.read_sql_query("""pragma table_info('language')
""",conn)
language_schema
# Out:
#    cid  name     type  notnull dflt_value  pk
# 0    0    id  INTEGER        0       None   0
# 1    1  name     TEXT        0       None   0

# %%
medium_schema=pd.read_sql_query("""pragma table_info('medium')
""",conn)
medium_schema
# Out:
#    cid      name     type  notnull dflt_value  pk
# 0    0        id  INTEGER        0       None   0
# 1    1   release  INTEGER        0       None   0
# 2    2  position  INTEGER        0       None   0
# 3    3    format  INTEGER        0       None   0
# 4    4      name     TEXT        0       None   0

# %%
medium_format_schema=pd.read_sql_query("""pragma table_info('medium_format')
""",conn)
medium_format_schema
# Out:
#    cid         name     type  notnull dflt_value  pk
# 0    0           id  INTEGER        0       None   0
# 1    1         name     TEXT        0       None   0
# 2    2  description     TEXT        0       None   0

# %%
release_schema=pd.read_sql_query("""pragma table_info('release')
""",conn)
release_schema
# Out:
#    cid           name     type  notnull dflt_value  pk
# 0    0             id  INTEGER        0       None   0
# 1    1           name     TEXT        0       None   0
# 2    2  artist_credit  INTEGER        0       None   0
# 3    3         status  INTEGER        0       None   0
# 4    4       language  INTEGER        0       None   0
# 5    5        comment     TEXT        0       None   0

# %%
release_info_schema=pd.read_sql_query("""pragma table_info('release_info')
""",conn)
release_info_schema
# Out:
#    cid        name     type  notnull dflt_value  pk
# 0    0     release  INTEGER        0       None   0
# 1    1        area  INTEGER        0       None   0
# 2    2   date_year  INTEGER        0       None   0
# 3    3  date_month  INTEGER        0       None   0
# 4    4    date_day  INTEGER        0       None   0

# %%
release_status_schema=pd.read_sql_query("""pragma table_info('release_status')
""",conn)
release_status_schema
# Out:
#    cid         name     type  notnull dflt_value  pk
# 0    0           id  INTEGER        0       None   0
# 1    1         name     TEXT        0       None   0
# 2    2  description     TEXT        0       None   0

# %%
work_schema=pd.read_sql_query("""pragma table_info('work')
""",conn)
work_schema
# Out:
#    cid     name     type  notnull dflt_value  pk
# 0    0       id  INTEGER        0       None   0
# 1    1     name     TEXT        0       None   0
# 2    2     type  INTEGER        0       None   0
# 3    3  comment     TEXT        0       None   0

# %%
work_type_schema=pd.read_sql_query("""pragma table_info('work_type')
""",conn)
work_type_schema
# Out:
#    cid         name     type  notnull dflt_value  pk
# 0    0           id  INTEGER        0       None   0
# 1    1         name     TEXT        0       None   0
# 2    2  description     TEXT        0       None   0

# %% [markdown]
# ### Q1 (q1_sample):
# The purpose of this query is to make sure that the formatting of your output matches exactly the formatting of our auto-grading script.<br>
# * Details: List all types of work ordered by type ascendingly.

# %%
name = pd.read_sql_query("""
select name from work_type
order by name ASC
""",conn)
name
# Out:
#                 name
# 0               Aria
# 1        Audio drama
# 2             Ballet
# 3      Beijing opera
# 4            Cantata
# 5           Concerto
# 6   Incidental music
# 7           Madrigal
# 8               Mass
# 9              Motet
# 10           Musical
# 11             Opera
# 12          Operetta
# 13          Oratorio
# 14          Overture
# 15           Partita
# 16              Play
# 17              Poem
# 18             Prose
# 19           Quartet
# 20            Sonata
# 21              Song
# 22        Song-cycle
# 23        Soundtrack
# 24             Suite
# 25    Symphonic poem
# 26          Symphony
# 27          Zarzuela
# 28             Étude

# %% [markdown]
# ### Q2 (q2_long_name):
# List works with the longest name of each type.<br>
# * Details: For each work type, find works that have the longest names. There might be cases where there is a tie for the longest names - in that case, return all of them. Display work names and corresponding type names, and order it according to work type (ascending) and use work name (ascending) as tie-breaker.

# %%
join = pd.read_sql_query(""" Select work.id,work.name, work.type, work_type.name, work_type.description 
from work
inner join work_type on work.id=work_type.id""",conn)
join
# Out:
#    id                   name  type            name  \
# 0  17                 Lately    17            Song
# 1  19         Safe From Harm    17        Zarzuela
# 2  16  Hymn of the Big Wheel    17        Symphony
# 3  15             Blue Lines    17      Song-cycle
# 4  10            Daydreaming    17           Opera
# 5  11          Five Man Army    17        Oratorio
# 6  18               One Love    17  Symphonic poem
#
#                                          description
# 0  A song is in its origin (and still in most cas...
# 1  A zarzuela is a Spanish lyric-dramatic work th...
# 2  A symphony is an extended composition, almost ...
# 3  A song cycle is a group of songs designed to b...
# 4  An opera is a dramatised work (text + musical ...
# 5  An oratorio is a large (usually sacred) musica...
# 6  A symphonic poem is a piece of programmatic or...

# %%
leagues = pd.read_sql("""SELECT *
                        FROM work
                        JOIN work_type ON work_type.id = work.id;""", conn)
leagues
# Out:
#    id                   name  type comment  id            name  \
# 0  17                 Lately    17          17            Song
# 1  19         Safe From Harm    17          19        Zarzuela
# 2  16  Hymn of the Big Wheel    17          16        Symphony
# 3  15             Blue Lines    17          15      Song-cycle
# 4  10            Daydreaming    17          10           Opera
# 5  11          Five Man Army    17          11        Oratorio
# 6  18               One Love    17          18  Symphonic poem
#
#                                          description
# 0  A song is in its origin (and still in most cas...
# 1  A zarzuela is a Spanish lyric-dramatic work th...
# 2  A symphony is an extended composition, almost ...
# 3  A song cycle is a group of songs designed to b...
# 4  An opera is a dramatised work (text + musical ...
# 5  An oratorio is a large (usually sacred) musica...
# 6  A symphonic poem is a piece of programmatic or...
